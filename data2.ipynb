# %%
a = 1

# %%
def add(a, b):
    return a + b

def add(a, b):
    return a + b

def add(a, b):
    return a + b

def add(a, b):
    return a + b

def add(a, b):
    return a + b

def add(a, b):
    return a + b

def add(a, b):
    return a + b

def add(a, b):
    return a + b

# %%
sreenand = 21
